# %% [markdown]
# <a href="https://colab.research.google.com/github/manamendraJN/SE4050-LabSheet-01/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Q1

# %%
scale = 1.0
size = (4, 4)

arr = np.random.exponential(scale=scale, size=size)

print(arr)
# Out:
# [[0.0093901  0.7954869  0.2229642  0.44727932]
#  [1.32411609 0.63553814 0.71565016 0.28909564]
#  [2.6360137  0.49919938 0.10148297 1.34291622]
#  [2.39306963 0.39165529 1.68615122 0.49647574]]

# %% [markdown]
# #Q2

# %%
uniform_data = np.random.rand(100000)
normal_data = np.random.randn(100000)
exponential_data = np.random.exponential(scale=1.0, size=100000)

plt.hist(uniform_data, density=True, bins=100, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=100, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=100, histtype="step", color="red", label="Exponential")

plt.axis([-2.5, 7, 0, 1.1])
plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# #Q3

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)

X,Y = np.meshgrid(x,y)
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

plt.show()

# %% [markdown]
# #Q4

# %%
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

df.head()

stats_df = df.select_dtypes(include=['number'])
corr = stats_df.corr()
corr

plt.figure(figsize=(9,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Pearson Standard Coefficient and Spearman Rank Correlation")
plt.show()
